# %%
"""
Created By    : Jared W. Marquis
Creation Date : 01 August 2022
Course        : ATSC 528 - Atmospheric Data Analysis
Assignment    : #04 - Chaos

Purpose:
Script to examine how chaos manifests in simple model.
[PUT MORE INFORMATION HERE - I.E., WHAT SPECIFIC THING IS BEING DONE]

"""
__author__    = "Jared W. Marquis"
__contact__   = "jared.marquis@und.edu"

# %%
### Import Required Modules (shouldn't need to change) ###
import numpy as np                 #numpy for math
import matplotlib.pyplot as plt    #matplotlib for plotting
import cartopy.crs as ccrs         #cartopy for plotting on map
import cartopy.feature as cfeature #cartopy basic shapefiles

# %%
a = 0.25
b = 4.0
F = 8.0
G = 1.0

(x0,y0,z0) = (2.5, 1.0, 0.0)
(x01,y01,z01) = (2.49, 1.0, 0.0)

# %%
time_step = 4/(24*5)
time_units = 120/5 #normalized time
times = np.arange(0,24.01,time_step)

# %%
def n_t(x, y, z, time_diff):
    x_n = x + time_diff*(-(y**2) - (z**2) - a*x + a*F)
    y_n = y + time_diff*(x*y - b*x*z - y + G)
    z_n = z + time_diff*(b*x*y + x*z - z)
    return (x_n, y_n, z_n)

# %%
(x,y,z) = (x0,y0,z0)
sim0 = np.zeros((len(times),3))
for idx in range (1,len(times)):
    (x,y,z) = n_t(x,y,z,time_step)
    sim0[idx] = (x,y,z)


(x1,y1,z1) = (x01,y01,z01)
sim1 = np.zeros((len(times),3))
for idx in range(1,len(times)):
    (x1,y1,z1) = n_t(x1,y1,z1,time_step)
    sim1[idx] = (x1,y1,z1)

# %%
times2 = times*5

# %%
ig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 10))
ax1.plot(times2,sim0[:,0],label='Sim 1')
ax1.plot(times2,sim1[:,0], label = 'Sim 2')
ax1.set_ylabel('X Values')
minor_ticks = np.arange(-3, 3, 0.5)
ax1.set_yticks(minor_ticks, minor=True)
ax1.grid(which='both', alpha=0.3)
ax1.legend()


ax2.plot(times2,sim0[:,1],label='Sim 1')
ax2.plot(times2,sim1[:,1],label = 'Sim 2')
ax2.set_ylabel('Y Values')
minor_ticks = np.arange(-3, 3, 0.5)
ax2.set_yticks(minor_ticks)
ax2.grid(which='both', alpha=0.3)
ax2.legend()


ax3.plot(times2,sim0[:,2],label='Sim 1')
ax3.plot(times2,sim1[:,2],label = 'Sim 2')
ax3.set_ylabel('Z Values')
ax3.set_xlabel('Time (Days)')
minor_ticks = np.arange(-3, 3, 0.5)
ax3.set_yticks(minor_ticks)
ax3.grid(which='both', alpha=0.3)
ax3.legend()

# %%
### In a separte text file (or below), provide a discussion of your results ###
### Make sure to answer the following questions in your discussion          ###
### 1 - Are the two simulations the same throughout the entire period?      ###
###     If not, when do they diverge?                                       ###
### 2 - If the ending points are different, what does this say regarding    ###
###     the importance of providing NWP models, assuming this serves as a   ###
###     proxy for one, with accurate and balanced initial conditions?       ###
'''
    

'''
# Out:
# '\n    \n\n'

# %% [markdown]
# The simulations are similar in the start of the time period, howevere as time progresses they diverge in thier solutions. For about the first 70-75 days the main diffrences are small changes in amplitude. However, after that period we end up getting cases where we have differences in the sign of the values at the same time. In some cases they start to converge to a similar solution again, but mostly they differ. This is to say that if this was an NWP model, the input of a balanced flow is important, due to the highly non-linear nature of the equations, a non balanced or inaccurate flow could result in wildly different outcomes and a drop in forecast skill.
